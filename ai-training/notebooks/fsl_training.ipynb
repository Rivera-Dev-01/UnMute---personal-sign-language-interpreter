# %% [markdown]
# # FSL (Filipino Sign Language) Model Training
#
# Train AI model to recognize 5 FSL signs:
# - KAMUSTA
# - SALAMAT
# - TULONG
# - OO
# - HINDI

# %%
# Import libraries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import cv2

# %%
# Load dataset from recorded videos
# Preprocess frames
# Build CNN model
# Train model
# Save model as fsl_model.h5
